# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenChigurla/GrowTech-Tasks/blob/main/Task_2_Housing_Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Assignment on Housing Dataset
#
#
#
# Make sure to load the dataset before starting:
# ```python
# import pandas as pd
#
# df = pd.read_csv("Housing.csv")
# df.head()
# ```

# %%
import pandas as pd

df = pd.read_csv("Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ### 1. Display the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# ### 2. Show the shape of the dataset.

# %%
df.shape
# Out:
# (545, 13)

# %% [markdown]
# ### 3. List all column names in the dataset.

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ### 4. Check for missing values in each column.

# %%
df[:].isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ### 5. Display the summary statistics for numerical columns.

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ### 6. How many unique values are there in the 'furnishingstatus' column?

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %% [markdown]
# ### 7. What is the average price of the houses?

# %%
df['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %% [markdown]
# ### 8. Find the median area of the houses.

# %%
df['area'].median()
# Out:
# 4600.0

# %% [markdown]
# ### 9. Count how many houses have 4 or more bedrooms.

# %%
df[df['bedrooms']>=4]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 6    10150000  8580         4          3        4      yes        no       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 487   2870000  5400         4          1        2      yes        no       no
# 488   2852500  5200         4          1        3      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 534   2100000  3000         4          1        2      yes        no       no
# 536   1960000  3420         5          1        2       no        no       no
#
# ...

# %%
len(df[df['bedrooms']>=4])
# Out:
# 107

# %% [markdown]
# ### 10. Show the number of houses with parking space for more than 1 car.

# %%
df[df['parking']>1]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 448   3150000  4095         2          1        1      yes        no       no
# 452   3150000  9000         3          1        2      yes        no       no
# 467   3010000  3240         3          1        2      yes        no       no
# 472   3010000  3630         4          1        2      yes        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
#
# ...

# %%
len(df[df['parking']>1])
# Out:
# 120

# %% [markdown]
# ### 11. Display the houses with both guestroom and basement.

# %%
df[(df['guestroom']=='yes') & (df['basement']=='yes')]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# 11    9681000  6000         4          3        2      yes       yes      yes
# 16    9100000  6600         4          2        2      yes       yes      yes
# 21    8680000  7155         3          2        1      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 375   3640000  5960         3          1        2      yes       yes      yes
# 415   3395000  4785         3          1        2      yes       yes      yes
# 432   3290000  6060         3          1        1      yes       yes      yes
# 446   3150000  3986         2          2        1       no       yes      yes
# 463   3080000  3090         2          1        1      yes       yes      yes
#
# ...

# %% [markdown]
# ### 12. How many houses are there with air conditioning but no hot water heating?

# %%
df[(df['airconditioning']=='yes') & (df['hotwaterheating']=='no')]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 457   3115000  3000         3          1        1       no        no       no
# 461   3080000  4960         2          1        1      yes        no      yes
# 504   2653000  3185         2          1        1      yes        no       no
# 505   2653000  4000         3          1        2      yes        no       no
# 531   2233000  5300         3          1        1       no        no       no
#
# ...

# %%
len(df[(df['airconditioning']=='yes') & (df['hotwaterheating']=='no')])
# Out:
# 171

# %% [markdown]
# ### 13. Create a new column 'price_per_sqft' (price divided by area).

# %%
df['price_per_sqft']=df['price']/df['area']
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ### 14. What is the average price per square foot?

# %%
df['price_per_sqft'].mean()
# Out:
# np.float64(993.3269783651732)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ### 15. Group the data by 'furnishingstatus' and find the average price for each group.

# %%
x=df.groupby('furnishingstatus')
x['price'].mean()
# Out:
# furnishingstatus
# furnished         5.495696e+06
# semi-furnished    4.907524e+06
# unfurnished       4.013831e+06
# Name: price, dtype: float64

# %% [markdown]
# ### 16. Find the number of houses located on the main road.

# %%
df[df['mainroad']=='yes']
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 537   1890000  1700         3          1        2      yes        no       no
# 538   1890000  3649         2          1        1      yes        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# 542   1750000  3620         2          1        1      yes        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
len(df[df['mainroad']=='yes'])
# Out:
# 468

# %% [markdown]
# ### 17. Show the distribution of the 'stories' column using value counts.

# %%
df['stories'].value_counts()
# Out:
# stories
# 2    238
# 1    227
# 4     41
# 3     39
# Name: count, dtype: int64

# %% [markdown]
# ### 18. How many houses have 2 bathrooms and are located in a preferred area?

# %%
df[(df['bathrooms']==2) & (df['prefarea']=='yes')]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000   7420         4          2        3      yes        no
# 2    12250000   9960         3          2        2      yes        no
# 3    12215000   7500         4          2        2      yes        no
# 9     9800000   5750         3          2        4      yes       yes
# 12    9310000   6550         4          2        2      yes        no
# 14    9240000   7800         3          2        2      yes        no
# 16    9100000   6600         4          2        2      yes       yes
# 19    8855000   6420         3          2        2      yes        no
# 25    8540000   6540         4          2        2      yes       yes
# 26    8463000   6000         3          2        4      yes       yes
# 29    8400000   5500         4          2        2      yes        no
# 32    8295000   4880         4          2        2      yes        no
# ...

# %%
len(df[(df['bathrooms']==2) & (df['prefarea']=='yes')])
# Out:
# 40

# %% [markdown]
# ### 19. What is the maximum and minimum area of a house?

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking  price_per_sqft
# count  545.000000      545.000000
# mean     0.693578      993.326978
# std      0.861586      346.537025
# min      0.000000      270.395550
# 25%      0.000000      745.370370
# 50%      0.000000      952.380952
# 75%      1.000000     1184.615385
# max      3.000000     2640.000000

# %%
df['area'].min()
# Out:
# 1650

# %%
df['area'].max()
# Out:
# 16200

# %% [markdown]
# ### 20. Sort the dataset by price in descending order.

# %%
df.sort_values('price',ascending=False)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ### 24. Replace 'yes' and 'no' with True and False across the dataset.

# %%
import numpy as np
df2=df
df2[:]=np.where(df.values=='yes',True,np.where(df.values == 'no', False, df.values))

df2
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %%
df.replace(['yes', 'no'],['True','False'])
# Out:
# /tmp/ipykernel_3998/538738943.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['yes', 'no'],['True','False'])
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3      True      False
# 1    12250000  8960         4          4        4      True      False
# 2    12250000  9960         3          2        2      True      False
# 3    12215000  7500         4          2        2      True      False
# 4    11410000  7420         4          1        2      True       True
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1      True      False
# ...

# %% [markdown]
# ### 25. Find out the average area of unfurnished houses.

# %%
df[df['furnishingstatus']=='unfurnished']
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2     True     False
# 9     9800000   5750         3          2        4     True      True
# 16    9100000   6600         4          2        2     True      True
# 21    8680000   7155         3          2        1     True      True
# 28    8400000   7950         5          2        2     True     False
# ..        ...    ...       ...        ...      ...      ...       ...
# 538   1890000   3649         2          1        1     True     False
# 539   1855000   2990         2          1        1    False     False
# 540   1820000   3000         2          1        1     True     False
# 542   1750000   3620         2          1        1     True     False
# 544   1750000   3850         3          1        2     True     False
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df[df['furnishingstatus']=='unfurnished']['price']
# Out:
# 7      10150000
# 9       9800000
# 16      9100000
# 21      8680000
# 28      8400000
#          ...
# 538     1890000
# 539     1855000
# 540     1820000
# 542     1750000
# 544     1750000
# Name: price, Length: 178, dtype: int64

# %%
(df[df['furnishingstatus']=='unfurnished']['price']).mean()
# Out:
# np.float64(4013831.4606741574)

# %% [markdown]
# ### 26. Filter out houses with price above the average price.

# %%
df['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %%
df[df['price']>df['price'].mean()]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 217   4830000  6862         3          1        2     True     False    False
# 218   4830000  4815         2          1        1     True     False    False
# 219   4795000  7000         3          1        2     True     False     True
# 220   4795000  8100         4          1        4     True     False     True
# 221   4767000  3420         4          2        2     True     False    False
#
# ...

# %% [markdown]
# ### 27. Identify the house with the highest price and display all its features.

# %%
df3=df
df3.sort_values('price',ascending=False)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 1    12250000  8960         4          4        4     True     False    False
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %%
df3.iloc[0]
# Out:
# price                 13300000
# area                      7420
# bedrooms                     4
# bathrooms                    2
# stories                      3
# mainroad                  True
# guestroom                False
# basement                 False
# hotwaterheating          False
# airconditioning           True
# parking                      2
# prefarea                  True
# furnishingstatus     furnished
# price_per_sqft      1792.45283
# Name: 0, dtype: object

# %% [markdown]
# ### 28. How many houses are both furnished and have at least 3 bathrooms?

# %%
df[(df['furnishingstatus']=='furnished') & (df['bathrooms']>=3)]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 1   12250000  8960         4          4        4     True     False    False
# 89   6440000  8580         5          3        2     True     False    False
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 1            False            True        3    False        furnished
# 89           False           False        2    False        furnished
#
#     price_per_sqft
# 1      1367.187500
# 89      750.582751

# %%
len(df[(df['furnishingstatus']=='furnished') & (df['bathrooms']>=3)])
# Out:
# 2

# %% [markdown]
# ### 29. Create a pivot table showing average price by 'furnishingstatus' and 'airconditioning'.

# %%
pd.pivot_table(
    df,
    values='price',
    index='furnishingstatus',
    columns='airconditioning',
    aggfunc='mean'
    )
# Out:
# airconditioning          False         True
# furnishingstatus
# furnished         4.469500e+06  6.786717e+06
# semi-furnished    4.557951e+06  5.778769e+06
# unfurnished       3.583342e+06  5.286167e+06

# %% [markdown]
# ### 30. Save the modified dataset with a new column into a new CSV file named 'Modified_Housing.csv'.

# %%
df5=df
df5
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %%
df5['balcony']=np.random.choice(['yes','no'],size=len(df5))
df5.to_csv('Modified_Housing.csv')

# %%
df5[df5['balcony']=='yes']
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# 5    10850000  7500         3          3        1     True     False     True
# 6    10150000  8580         4          3        4     True     False    False
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 533   2100000  2400         3          1        2     True     False    False
# 536   1960000  3420         5          1        2    False     False    False
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %%
df5[df5['balcony']=='no']
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000   7420         4          2        3     True     False
# 1    12250000   8960         4          4        4     True     False
# 7    10150000  16200         5          3        2     True     False
# 8     9870000   8100         4          1        2     True      True
# 10    9800000  13200         3          1        2     True     False
# ..        ...    ...       ...        ...      ...      ...       ...
# 537   1890000   1700         3          1        2     True     False
# 538   1890000   3649         2          1        1     True     False
# 539   1855000   2990         2          1        1    False     False
# 542   1750000   3620         2          1        1     True     False
# 543   1750000   2910         3          1        1    False     False
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# ### 31.Find the top 5 most expensive houses for each furnishing status.

# %%
x=df.groupby('furnishingstatus')['price'].nlargest(5)
x
# Out:
# furnishingstatus
# furnished         0     13300000
#                   1     12250000
#                   3     12215000
#                   4     11410000
#                   8      9870000
# semi-furnished    2     12250000
#                   5     10850000
#                   6     10150000
#                   11     9681000
#                   12     9310000
# unfurnished       7     10150000
#                   9      9800000
#                   16     9100000
#                   21     8680000
#                   28     8400000
# Name: price, dtype: int64

# %% [markdown]
# ### 32 Create a new column 'luxury' where a house is considered luxury if it has price > 1.5× mean and is in a preferred area.

# %%
df4=df
df4['luxury']=(df4['price'])> (1.5 * df4['price'].mean())
df4
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %% [markdown]
# ### For each number of stories, calculate the median price, and standard deviation of area.

# %%
df.groupby('stories').agg({'price':'median', 'area':'std'})
# Out:
#              price         area
# stories
# 1        3850000.0  2275.977836
# 2        4308500.0  2122.466037
# 3        5873000.0  1977.331302
# 4        7350000.0  1197.437867

# %% [markdown]
# ### Pivot the data to show average price with bedrooms as rows and stories as columns.

# %%
pd.pivot_table(
    df,
    values='price',
    index='bedrooms',
    columns='stories',
    aggfunc='mean'
)
# Out:
# stories              1             2             3             4
# bedrooms
# 1         2.712500e+06           NaN           NaN           NaN
# 2         3.580165e+06  3.777550e+06           NaN  6.685000e+06
# 3         4.800441e+06  4.535290e+06  5.585548e+06  7.193458e+06
# 4         5.122250e+06  5.405292e+06  6.140000e+06  7.268333e+06
# 5         3.773000e+06  6.103125e+06  5.600000e+06           NaN
# 6                  NaN  4.791500e+06           NaN           NaN

# %%
pd.pivot_table(
    df,
    values='price',
    index='bedrooms',
    columns='stories',
    aggfunc='mean',
    fill_value=0
)
# Out:
# stories              1             2             3             4
# bedrooms
# 1         2.712500e+06  0.000000e+00  0.000000e+00  0.000000e+00
# 2         3.580165e+06  3.777550e+06  0.000000e+00  6.685000e+06
# 3         4.800441e+06  4.535290e+06  5.585548e+06  7.193458e+06
# 4         5.122250e+06  5.405292e+06  6.140000e+06  7.268333e+06
# 5         3.773000e+06  6.103125e+06  5.600000e+06  0.000000e+00
# 6         0.000000e+00  4.791500e+06  0.000000e+00  0.000000e+00

# %%
df.pivot_table(
    values='price',
    index='bedrooms',
    columns='stories',
    aggfunc='mean'
)
# Out:
# stories              1             2             3             4
# bedrooms
# 1         2.712500e+06           NaN           NaN           NaN
# 2         3.580165e+06  3.777550e+06           NaN  6.685000e+06
# 3         4.800441e+06  4.535290e+06  5.585548e+06  7.193458e+06
# 4         5.122250e+06  5.405292e+06  6.140000e+06  7.268333e+06
# 5         3.773000e+06  6.103125e+06  5.600000e+06           NaN
# 6                  NaN  4.791500e+06           NaN           NaN

# %% [markdown]
# ### Using groupby, find the proportion of houses in each 'furnishingstatus' that have air conditioning.

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %% [markdown]
# ### Group by 'furnishingstatus' and 'airconditioning' and calculate the average price and average area.

# %%
df.groupby(['furnishingstatus','airconditioning']).mean(['price','area'])
# Out:
#                                          price         area  bedrooms  \
# furnishingstatus airconditioning
# furnished        False            4.469500e+06  5157.448718  2.871795
#                  True             6.786717e+06  6355.693548  3.306452
# semi-furnished   False            4.557951e+06  4935.320988  2.962963
#                  True             5.778769e+06  5742.107692  3.123077
# unfurnished      False            3.583342e+06  4490.353383  2.796992
#                  True             5.286167e+06  5349.666667  2.933333
#
#                                   bathrooms   stories   parking  \
# furnishingstatus airconditioning
# furnished        False             1.269231  1.666667  0.717949
#                  True              1.516129  2.290323  1.096774
# semi-furnished   False             1.253086  1.685185  0.672840
#                  True              1.430769  2.092308  0.892308
# unfurnished      False             1.157895  1.548872  0.443609
# ...

# %% [markdown]
# ### Calculate the average number of bedrooms per furnishing status, only for houses with area > 5000

# %%
df[df['area']>5000].groupby('furnishingstatus').mean('bedrooms')
# Out:
#                          price         area  bedrooms  bathrooms   stories  \
# furnishingstatus
# furnished         6.507146e+06  7486.360000  3.146667   1.480000  2.093333
# semi-furnished    5.778893e+06  7050.602041  3.132653   1.387755  1.846939
# unfurnished       5.386000e+06  6766.777778  3.031746   1.365079  2.079365
#
#                    parking  price_per_sqft    luxury
# furnishingstatus
# furnished         1.213333      898.329850  0.293333
# semi-furnished    0.918367      854.239404  0.204082
# unfurnished       0.777778      823.488365  0.190476

# %% [markdown]
# ### For each unique combination of bedrooms and bathrooms, compute the average price.

# %%
df.groupby(['bedrooms', 'bathrooms'])['price'].mean().reset_index()
# Out:
#     bedrooms  bathrooms         price
# 0          1          1  2.712500e+06
# 1          2          1  3.596852e+06
# 2          2          2  4.194750e+06
# 3          3          1  4.463484e+06
# 4          3          2  6.379569e+06
# 5          3          3  6.807500e+06
# 6          4          1  4.710583e+06
# 7          4          2  6.358990e+06
# 8          4          3  7.250250e+06
# 9          4          4  1.225000e+07
# 10         5          1  4.996250e+06
# 11         5          2  5.405750e+06
# 12         5          3  8.295000e+06
# 13         6          1  3.500000e+06
# 14         6          2  6.083000e+06

# %% [markdown]
# ### Find the top 10% most expensive houses within each furnishingstatus category.

# %%
df.groupby('furnishingstatus').apply( lambda x: x[x['price'] >= x['price'].quantile(0.90)] )
# Out:
# /tmp/ipykernel_3998/2290538846.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('furnishingstatus').apply( lambda x: x[x['price'] >= x['price'].quantile(0.90)] )
#                         price   area  bedrooms  bathrooms  stories mainroad  \
# furnishingstatus
# furnished        0   13300000   7420         4          2        3     True
#                  1   12250000   8960         4          4        4     True
#                  3   12215000   7500         4          2        2     True
#                  4   11410000   7420         4          1        2     True
#                  8    9870000   8100         4          1        2     True
# ...

# %% [markdown]
# ### Replace all values in furnishingstatus with their uppercase equivalents.

# %%
df['furnishingstatus'].str.capitalize()
# Out:
# 0           Furnished
# 1           Furnished
# 2      Semi-furnished
# 3           Furnished
# 4           Furnished
#             ...
# 540       Unfurnished
# 541    Semi-furnished
# 542       Unfurnished
# 543         Furnished
# 544       Unfurnished
# Name: furnishingstatus, Length: 545, dtype: object

# %%
df['furnishingstatus'].str.upper()
# Out:
# 0           FURNISHED
# 1           FURNISHED
# 2      SEMI-FURNISHED
# 3           FURNISHED
# 4           FURNISHED
#             ...
# 540       UNFURNISHED
# 541    SEMI-FURNISHED
# 542       UNFURNISHED
# 543         FURNISHED
# 544       UNFURNISHED
# Name: furnishingstatus, Length: 545, dtype: object

# %%
df['furnishingstatus']=df['furnishingstatus'].replace({'furnished':'FURNISHED','semi-furnished':'SEMI-FURNISHED','unfurnished':'UNFURNISHED'})
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3     True     False    False
# 1    12250000  8960         4          4        4     True     False    False
# 2    12250000  9960         3          2        2     True     False     True
# 3    12215000  7500         4          2        2     True     False     True
# 4    11410000  7420         4          1        2     True      True     True
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1     True     False     True
# 541   1767150  2400         3          1        1    False     False    False
# 542   1750000  3620         2          1        1     True     False    False
# 543   1750000  2910         3          1        1    False     False    False
# 544   1750000  3850         3          1        2     True     False    False
#
# ...

# %% [markdown]
# ### Use .pivot_table() with multiple aggregation functions (mean, max, std) for price grouped by stories and parking.

# %%
pd.pivot_table(df,
               values='price',
               index='stories',
               columns='parking',
               aggfunc=['mean','max','std']

               )
# Out:
#                  mean                                                   max  \
# parking             0             1             2             3           0
# stories
# 1        3.695366e+06  4.428356e+06  5.117571e+06  4.565167e+06   7420000.0
# 2        4.079344e+06  5.239105e+06  6.093000e+06  6.241667e+06  10150000.0
# 3        5.343722e+06  5.798917e+06  7.109667e+06           NaN   7560000.0
# 4        6.334500e+06  7.315000e+06  7.952585e+06  8.096667e+06   8463000.0
#
#                                                      std                \
# parking          1           2           3             0             1
# stories
# 1        8645000.0  10850000.0   6300000.0  1.096730e+06  1.642325e+06
# 2        9310000.0  12250000.0  12215000.0  1.279300e+06  1.877771e+06
# 3        8043000.0  13300000.0         NaN  1.270940e+06  1.414739e+06
# 4        9800000.0  10150000.0  12250000.0  9.723566e+05  9.500636e+05
#
#
# parking             2             3
# stories
# ...
