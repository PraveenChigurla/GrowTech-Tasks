# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenChigurla/GrowTech-Tasks/blob/main/Task_3_pandas_task1_adult.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('adult.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ### 1) Which education level has the largest representation in the dataset? Show counts in descending order.

# %%
df.groupby(['education'])['education'].count().sort_values(ascending=False)
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %% [markdown]
# ### 2) What are the top 3 occupations for people earning >50K?

# %%
df[df['income']=='>50K'].groupby('occupation')['occupation'].count().sort_values(ascending=False).head(3)
# Out:
# occupation
# Exec-managerial    2908
# Prof-specialty     2784
# Sales              1475
# Name: occupation, dtype: int64

# %% [markdown]
# ### 3) Find the average hours-per-week worked by each marital-status.

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.groupby('marital-status')['hours-per-week'].mean().reset_index()
# Out:
#           marital-status  hours-per-week
# 0               Divorced       41.115483
# 1      Married-AF-spouse       39.810811
# 2     Married-civ-spouse       43.306984
# 3  Married-spouse-absent       39.684713
# 4          Never-married       36.891357
# 5              Separated       39.667974
# 6                Widowed       33.438076

# %% [markdown]
# ### 4) Identify the top 5 native countries (excluding the US) of people earning >50K.

# %%
x=df[(df['income']=='>50K')& (df['native-country']!='United-States')]
x['native-country'].value_counts().head(5)
# Out:
# native-country
# ?              220
# Philippines     85
# Canada          63
# India           62
# Germany         58
# Name: count, dtype: int64

# %%
x=df[(df['income']=='>50K')& (df['native-country']!='United-States')]
x.groupby('native-country')['native-country'].count().sort_values(ascending=False).head(5)          #'value_counts()' equivalent to 'count().sort_values(ascending=False)'
# Out:
# native-country
# ?              220
# Philippines     85
# Canada          63
# India           62
# Germany         58
# Name: native-country, dtype: int64

# %% [markdown]
# ### 5) Among people working 50+ hours/week, what proportion earn >50K?

# %%
x=df[df['hours-per-week']>50]
x
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 25      45  Self-emp-not-inc  432824       HS-grad                9
# 27      23           Private  134446       HS-grad                9
# 29      32  Self-emp-not-inc  109282  Some-college               10
# 53      22           Private   54164       HS-grad                9
# 54      38           Private  219446           9th                5
# ...    ...               ...     ...           ...              ...
# 48811   35                 ?  320084     Bachelors               13
# 48812   30                 ?   33811     Bachelors               13
# 48813   34           Private  204461     Doctorate               16
# 48817   34           Private  160216     Bachelors               13
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
#
#               marital-status         occupation   relationship  \
# 25        Married-civ-spouse       Craft-repair        Husband
# ...

# %%
x['income'].value_counts()
# Out:
# income
# <=50K    3212
# >50K     2223
# Name: count, dtype: int64

# %%
y=x['income'].value_counts(normalize=True)*100
y
# Out:
# income
# <=50K    59.098436
# >50K     40.901564
# Name: proportion, dtype: float64

# %%
y['>50K']
# Out:
# np.float64(40.9015639374425)

# %%
(df[df['hours-per-week']>50]['income'].value_counts(normalize=True)*100)['>50K']
# Out:
# np.float64(40.9015639374425)

# %% [markdown]
# ### 6) Find the age range of individuals with the highest capital-gain.

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
maxi=df['capital-gain'].max()
mini=df['capital-gain'].min()

min_age=df[df['capital-gain']==maxi]['age'].min()
max_age=df[df['capital-gain']==maxi]['age'].max()

print(f'age range={min_age}-{max_age}')
# Out:
# age range=21-80

# %% [markdown]
# ### 7) For each education, show how many people work part-time (hours-per-week < 35).

# %%
df[df['hours-per-week']<35].groupby('education')['hours-per-week'].count()
# Out:
# education
# 10th             388
# 11th             690
# 12th             216
# 1st-4th           53
# 5th-6th           87
# 7th-8th          210
# 9th              150
# Assoc-acdm       253
# Assoc-voc        220
# Bachelors        903
# Doctorate         64
# HS-grad         2302
# Masters          273
# Preschool         24
# Prof-school       84
# Some-college    2478
# Name: hours-per-week, dtype: int64

# %% [markdown]
# ### 8) What are the 5 most common combinations of workclass and occupation?

# %%
df[['workclass','occupation']].value_counts().head(5)
# Out:
# workclass  occupation
# Private    Craft-repair       4748
#            Sales              4439
#            Adm-clerical       4208
#            Other-service      4057
#            Exec-managerial    3995
# Name: count, dtype: int64

# %%
df.groupby(['workclass','occupation'])['occupation'].value_counts().sort_values(ascending=False).head(5)
# Out:
# workclass  occupation
# Private    Craft-repair       4748
#            Sales              4439
#            Adm-clerical       4208
#            Other-service      4057
#            Exec-managerial    3995
# Name: count, dtype: int64

# %% [markdown]
# ### 9) Among women (gender == 'Female'), which education level is most frequent for >50K earners?

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df[(df['income']=='>50K') & (df['gender']=='Female')]['education'].value_counts().head(1)
# Out:
# education
# Bachelors    521
# Name: count, dtype: int64

# %% [markdown]
# ### 10) Find the average age of people with Doctorate education level.

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df[df['education']=='Doctorate']['age'].mean()
# Out:
# np.float64(47.53030303030303)

# %% [markdown]
# ### 11) Group by age_bucket (<=25, 26-35, 36-45, 46-55, 56-65, >65) and show the income distribution in each group.

# %%
import pandas as pd
age_bins = [-float('inf'), 25, 35, 45, 55, 65, float('inf')]
# age_labels = ['<=25', '26-35', '36-45', '46-55', '56-65', '>65']


df['xy']=pd.cut(df['age'],bins=age_bins)#, labels=age_labels)
df['xy']
df.groupby('xy')['income'].value_counts()
# Out:
# /tmp/ipykernel_1650/183802640.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('xy')['income'].value_counts()
# xy            income
# (-inf, 25.0]  <=50K      9458
#               >50K        169
# (25.0, 35.0]  <=50K     10340
#               >50K       2379
# (35.0, 45.0]  <=50K      7821
#               >50K       4131
# (45.0, 55.0]  <=50K      5041
#               >50K       3255
# (55.0, 65.0]  <=50K      3049
#               >50K       1396
# (65.0, inf]   <=50K      1446
#               >50K        357
# Name: count, dtype: int64

# %% [markdown]
# ### 12) Find how many people work exactly 40 hours per week and their proportion of total.

# %%
len(df[df['hours-per-week']==40])/len(df)*100
# Out:
# 46.68727734327013

# %%
(df['hours-per-week']==40).mean()*100
# Out:
# np.float64(46.68727734327013)

# %% [markdown]
# ### 13) Show the top 3 education levels with the highest share of >50K earners.

# %%
df[df['income']=='>50K']['education'].value_counts().head(3)
# Out:
# education
# Bachelors       3313
# HS-grad         2503
# Some-college    2063
# Name: count, dtype: int64

# %% [markdown]
# ### 14) For each race, calculate the most common occupation.

# %%
df.groupby('race')['occupation'].value_counts().groupby(level=0).head(1)
# Out:
# race                occupation
# Amer-Indian-Eskimo  Craft-repair        61
# Asian-Pac-Islander  Prof-specialty     289
# Black               Other-service      824
# Other               Craft-repair        58
# White               Craft-repair      5504
# Name: count, dtype: int64

# %% [markdown]
# ### 15) Identify the top 5 most frequent marital-status + workclass pairs.

# %%
df.groupby(['marital-status','workclass'])['workclass'].count().sort_values(ascending=False).head()
# Out:
# marital-status      workclass
# Married-civ-spouse  Private             14473
# Never-married       Private             12243
# Divorced            Private              4702
# Married-civ-spouse  Self-emp-not-inc     2554
#                     Local-gov            1536
# Name: workclass, dtype: int64

# %%
df[['marital-status','workclass']].value_counts().head()
# Out:
# marital-status      workclass
# Married-civ-spouse  Private             14473
# Never-married       Private             12243
# Divorced            Private              4702
# Married-civ-spouse  Self-emp-not-inc     2554
#                     Local-gov            1536
# Name: count, dtype: int64

# %% [markdown]
# ### 16) Find the average age of people grouped by gender and income.

# %%
df.groupby(['gender','income'])['age'].mean()
# Out:
# gender  income
# Female  <=50K     36.278999
#         >50K      42.219333
# Male    <=50K     37.248548
#         >50K      44.641863
# Name: age, dtype: float64

# %% [markdown]
# ### 17) Which occupation has the highest proportion of >50K earners?

# %%
(df[df['income']=='>50K']['occupation'].value_counts(normalize=True).sort_values(ascending=False)*100)
# Out:
# occupation
# Exec-managerial      24.882348
# Prof-specialty       23.821340
# Sales                12.620861
# Craft-repair         11.833661
# Adm-clerical          6.571404
# Transport-moving      4.115684
# Tech-support          3.593737
# Machine-op-inspct     3.183024
# Protective-serv       2.635407
# ?                     2.267477
# Other-service         1.745529
# Farming-fishing       1.480277
# Handlers-cleaners     1.180799
# Armed-Forces          0.042783
# Priv-house-serv       0.025670
# Name: proportion, dtype: float64

# %%
(df[df['income']=='>50K']['occupation'].value_counts(normalize=True).sort_values(ascending=False)*100).nlargest(1)
# Out:
# occupation
# Exec-managerial    24.882348
# Name: proportion, dtype: float64

# %% [markdown]
# ### 18) Identify the top 3 native countries where people work more than 60 hours per week.

# %%
df[df['hours-per-week']>60]['native-country'].value_counts().sort_values(ascending=False).nlargest(3)
# Out:
# native-country
# United-States    1506
# ?                  33
# Mexico             31
# Name: count, dtype: int64

# %% [markdown]
# ### 19) Find how many people have a capital-loss > 0 and group them by income.

# %%
len(df[df['capital-loss']>0])
# Out:
# 2282

# %%
df[df['capital-loss']>0].groupby('income')['capital-loss'].count()
# Out:
# income
# <=50K    1138
# >50K     1144
# Name: capital-loss, dtype: int64

# %% [markdown]
# ### 20) Among people earning <=50K, find the most common education level.

# %%
df[df['income']=='<=50K']['education'].value_counts().head()
# Out:
# education
# HS-grad         13281
# Some-college     8815
# Bachelors        4712
# 11th             1720
# Assoc-voc        1539
# Name: count, dtype: int64

# %% [markdown]
# ### 21) Group people by hours-per-week ranges (<20, 20–39, 40, 41–59, >=60) and show the income distribution for each range.

# %%
hrs_range = [-float('inf'), 19, 39, 40, 59, float('inf')]
hrs_labels = ['<20', '20-39', '40', '41-59', '>=60']

df['hrs_grp'] = pd.cut(df['hours-per-week'], bins=hrs_range, labels=hrs_labels)
df
df.groupby(['hrs_grp'])['income'].value_counts()
# Out:
# /tmp/ipykernel_1650/1867618470.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['hrs_grp'])['income'].value_counts()
# hrs_grp  income
# <20      <=50K      2402
#          >50K        189
# 20-39    <=50K      8190
#          >50K        906
# 40       <=50K     17953
#          >50K       4850
# 41-59    <=50K      6310
#          >50K       4189
# >=60     <=50K      2300
#          >50K       1553
# Name: count, dtype: int64

# %% [markdown]
# ### 22) Which workclass group has the highest average capital-gain?

# %%
df.groupby('workclass')['capital-gain'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        5132.794100
# Self-emp-not-inc    1781.744692
# Federal-gov          923.287709
# Private              896.135374
# Local-gov            798.228635
# State-gov            756.336194
# ?                    502.946052
# Without-pay          325.238095
# Never-worked           0.000000
# Name: capital-gain, dtype: float64

# %% [markdown]
# ### 23) Find all individuals with Doctorate education working less than 20 hours per week.

# %%
df[df['education']=='Doctorate'][df['hours-per-week']<20]
# Out:
# /tmp/ipykernel_1650/1390096886.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['education']=='Doctorate'][df['hours-per-week']<20]
#        age         workclass  fnlwgt  education  educational-num  \
# 166     58  Self-emp-not-inc  159021  Doctorate               16
# 3733    77         State-gov  267799  Doctorate               16
# 9693    48         Local-gov  452402  Doctorate               16
# 11517   70                 ?  116080  Doctorate               16
# 13920   73  Self-emp-not-inc  110787  Doctorate               16
# 16470   58         State-gov  109567  Doctorate               16
# 18399   61                 ?  188172  Doctorate               16
# 20299   72                 ?  118902  Doctorate               16
# 20517   75  Self-emp-not-inc  231741  Doctorate               16
# 26465   42  Self-emp-not-inc  115323  Doctorate               16
# 27491   36  Self-emp-not-inc  188972  Doctorate               16
# ...

# %% [markdown]
# ### 24) Find the percentage of females in each workclass.

# %%
df.groupby('workclass')['gender'].value_counts(normalize=True).mul(100).unstack()
# Out:
# gender               Female       Male
# workclass
# ?                 45.373348  54.626652
# Federal-gov       31.564246  68.435754
# Local-gov         40.114796  59.885204
# Never-worked      30.000000  70.000000
# Private           34.209284  65.790716
# Self-emp-inc      12.448378  87.551622
# Self-emp-not-inc  16.286898  83.713102
# State-gov         38.515901  61.484099
# Without-pay       33.333333  66.666667

# %%
# Calculate the percentage of each gender within each workclass
gender_percentages = df.groupby('workclass')['gender'].value_counts(normalize=True).mul(100).unstack()

# Select and display only the female percentages
display(gender_percentages['Female'])
# Out:
# workclass
# ?                   45.373348
# Federal-gov         31.564246
# Local-gov           40.114796
# Never-worked        30.000000
# Private             34.209284
# Self-emp-inc        12.448378
# Self-emp-not-inc    16.286898
# State-gov           38.515901
# Without-pay         33.333333
# Name: Female, dtype: float64

# %%
((df.groupby(['workclass'])['gender']).value_counts(normalize=True).mul(100)).groupby(level=0).tail(1)
# Out:
# workclass         gender
# ?                 Female    45.373348
# Federal-gov       Female    31.564246
# Local-gov         Female    40.114796
# Never-worked      Female    30.000000
# Private           Female    34.209284
# Self-emp-inc      Female    12.448378
# Self-emp-not-inc  Female    16.286898
# State-gov         Female    38.515901
# Without-pay       Female    33.333333
# Name: proportion, dtype: float64

# %% [markdown]
# ### 25) Identify the oldest person in the dataset and display all their details.

# %%
df[df['age']==df['age'].max()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 899     90           Private  149069    Assoc-acdm               12
# 3496    90  Self-emp-not-inc   83601   Prof-school               15
# 6976    90           Private  250832       HS-grad                9
# 7414    90           Private  227796    Assoc-acdm               12
# 7419    90  Self-emp-not-inc  122348   Prof-school               15
# 8427    90       Federal-gov  311184       Masters               14
# 8982    90           Private  225063       HS-grad                9
# 10735   90         Local-gov  188242       HS-grad                9
# 11871   90                 ?   50746          10th                6
# 12446   90           Private  347074  Some-college               10
# 13958   90           Private  272752  Some-college               10
# 15088   90           Private  197613       HS-grad                9
# 16503   90           Private   51744       HS-grad                9
# ...

# %%
# Grabs the row(s) with the maximum age value
df.nlargest(1, 'age', keep='all')
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 899     90           Private  149069    Assoc-acdm               12
# 3496    90  Self-emp-not-inc   83601   Prof-school               15
# 6976    90           Private  250832       HS-grad                9
# 7414    90           Private  227796    Assoc-acdm               12
# 7419    90  Self-emp-not-inc  122348   Prof-school               15
# 8427    90       Federal-gov  311184       Masters               14
# 8982    90           Private  225063       HS-grad                9
# 10735   90         Local-gov  188242       HS-grad                9
# 11871   90                 ?   50746          10th                6
# 12446   90           Private  347074  Some-college               10
# 13958   90           Private  272752  Some-college               10
# 15088   90           Private  197613       HS-grad                9
# 16503   90           Private   51744       HS-grad                9
# ...

# %%
# Returns a single Series representing the first person with the maximum age
df.loc[df['age'].idxmax()]
# Out:
# age                                90
# workclass                     Private
# fnlwgt                         149069
# education                  Assoc-acdm
# educational-num                    12
# marital-status     Married-civ-spouse
# occupation                      Sales
# relationship                  Husband
# race                            White
# gender                           Male
# capital-gain                        0
# capital-loss                     1825
# hours-per-week                     50
# native-country          United-States
# income                           >50K
# xy                        (65.0, inf]
# hrs_grp                         41-59
# Name: 899, dtype: object

# %% [markdown]
# ### 26) Among all races, who works the least average hours per week?

# %%
df.groupby('race')['hours-per-week'].mean().sort_values()
# Out:
# race
# Black                 38.597866
# Other                 39.201970
# Asian-Pac-Islander    39.884793
# Amer-Indian-Eskimo    40.272340
# White                 40.660170
# Name: hours-per-week, dtype: float64

# %%
(df.groupby('race')['hours-per-week'].mean().sort_values()).nsmallest(2)
# Out:
# race
# Black    38.597866
# Other    39.201970
# Name: hours-per-week, dtype: float64

# %% [markdown]
# ### 27) Which marital-status group has the highest proportion of >50K earners?

# %%
df.groupby('marital-status')['income'].value_counts(normalize=True).mul(100).unstack().sort_values(by='>50K',ascending=False)
# Out:
# income                     <=50K       >50K
# marital-status
# Married-civ-spouse     55.386747  44.613253
# Married-AF-spouse      62.162162  37.837838
# Divorced               89.883914  10.116086
# Married-spouse-absent  90.764331   9.235669
# Widowed                91.567852   8.432148
# Separated              93.529412   6.470588
# Never-married          95.452007   4.547993

# %% [markdown]
# ### 28) Find the most frequent combination of education and income.

# %%
df.groupby('education')['income'].value_counts().sort_values(ascending=False).head(1)
# Out:
# education  income
# HS-grad    <=50K     13281
# Name: count, dtype: int64

# %% [markdown]
# ### 29) Group people by occupation and calculate how many have capital-gain > 0.

# %%
df[df['capital-gain']>0].groupby('occupation').size()
# Out:
# occupation
# ?                    174
# Adm-clerical         343
# Armed-Forces           1
# Craft-repair         478
# Exec-managerial      810
# Farming-fishing      103
# Handlers-cleaners     91
# Machine-op-inspct    190
# Other-service        174
# Priv-house-serv       10
# Prof-specialty       832
# Protective-serv       73
# Sales                470
# Tech-support         129
# Transport-moving     157
# dtype: int64

# %% [markdown]
# ### 30) Find the top 5 age values where people earn >50K.

# %%
df[df['income']=='>50K']['age'].max()
# Out:
# 90

# %%
df[df['income']=='>50K']['age'].value_counts().sort_values(ascending=False).head()
# Out:
# age
# 46    439
# 47    429
# 41    427
# 39    423
# 37    422
# Name: count, dtype: int64

# %%
df[df['income']=='>50K'].groupby('age')['age'].size().sort_values(ascending=False).head() #size() creating single index
# Out:
# age
# 46    439
# 47    429
# 41    427
# 39    423
# 37    422
# Name: age, dtype: int64

# %%
df[df['income']=='>50K'].groupby('age')['age'].value_counts().sort_values(ascending=False).head()  #value_counts() creating multiindex
# Out:
# age
# 46    439
# 47    429
# 41    427
# 39    423
# 37    422
# Name: count, dtype: int64
