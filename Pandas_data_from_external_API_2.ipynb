# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenChigurla/GrowTech-Tasks/blob/main/Pandas_data_from_external_API_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests
response=requests.get("https://dummyjson.com/products", allow_redirects=True)
response
# Out:
# <Response [200]>

# %%
print(response.headers.get('content-type'))
# Out:
# application/json; charset=utf-8

# %%
response.json()
# Out:
# {'products': [{'id': 1,
#    'title': 'Essence Mascara Lash Princess',
#    'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#    'category': 'beauty',
#    'price': 9.99,
#    'discountPercentage': 10.48,
#    'rating': 2.56,
#    'stock': 99,
#    'tags': ['beauty', 'mascara'],
#    'brand': 'Essence',
#    'sku': 'BEA-ESS-ESS-001',
#    'weight': 4,
#    'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#    'warrantyInformation': '1 week warranty',
#    'shippingInformation': 'Ships in 3-5 business days',
#    'availabilityStatus': 'In Stock',
#    'reviews': [{'rating': 3,
#      'comment': 'Would not recommend!',
#      'date': '2025-04-30T09:41:02.053Z',
#      'reviewerName': 'Eleanor Collins',
#      'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#     {'rating': 4,
#      'comment': 'Very satisfied!',
# ...

# %%
response.content
# Out:
# b'{"products":[{"id":1,"title":"Essence Mascara Lash Princess","description":"The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.","category":"beauty","price":9.99,"discountPercentage":10.48,"rating":2.56,"stock":99,"tags":["beauty","mascara"],"brand":"Essence","sku":"BEA-ESS-ESS-001","weight":4,"dimensions":{"width":15.14,"height":13.08,"depth":22.99},"warrantyInformation":"1 week warranty","shippingInformation":"Ships in 3-5 business days","availabilityStatus":"In Stock","reviews":[{"rating":3,"comment":"Would not recommend!","date":"2025-04-30T09:41:02.053Z","reviewerName":"Eleanor Collins","reviewerEmail":"eleanor.collins@x.dummyjson.com"},{"rating":4,"comment":"Very satisfied!","date":"2025-04-30T09:41:02.053Z","reviewerName":"Lucas Gordon","reviewerEmail":"lucas.gordon@x.dummyjson.com"},{"rating":5,"comment":"Highly impressed!","date":"2025-04-30T09:41:0
# ...

# %%
type(response.content)
# Out:
# bytes

# %%
import json
diction=json.loads(response.content)   #data converted from json to dictionary
diction
# Out:
# {'products': [{'id': 1,
#    'title': 'Essence Mascara Lash Princess',
#    'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#    'category': 'beauty',
#    'price': 9.99,
#    'discountPercentage': 10.48,
#    'rating': 2.56,
#    'stock': 99,
#    'tags': ['beauty', 'mascara'],
#    'brand': 'Essence',
#    'sku': 'BEA-ESS-ESS-001',
#    'weight': 4,
#    'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#    'warrantyInformation': '1 week warranty',
#    'shippingInformation': 'Ships in 3-5 business days',
#    'availabilityStatus': 'In Stock',
#    'reviews': [{'rating': 3,
#      'comment': 'Would not recommend!',
#      'date': '2025-04-30T09:41:02.053Z',
#      'reviewerName': 'Eleanor Collins',
#      'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#     {'rating': 4,
#      'comment': 'Very satisfied!',
# ...

# %%
type(diction)
# Out:
# dict

# %%
diction['products']
# Out:
# [{'id': 1,
#   'title': 'Essence Mascara Lash Princess',
#   'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#   'category': 'beauty',
#   'price': 9.99,
#   'discountPercentage': 10.48,
#   'rating': 2.56,
#   'stock': 99,
#   'tags': ['beauty', 'mascara'],
#   'brand': 'Essence',
#   'sku': 'BEA-ESS-ESS-001',
#   'weight': 4,
#   'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#   'warrantyInformation': '1 week warranty',
#   'shippingInformation': 'Ships in 3-5 business days',
#   'availabilityStatus': 'In Stock',
#   'reviews': [{'rating': 3,
#     'comment': 'Would not recommend!',
#     'date': '2025-04-30T09:41:02.053Z',
#     'reviewerName': 'Eleanor Collins',
#     'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#    {'rating': 4,
#     'comment': 'Very satisfied!',
#     'date': '2025-04-30T09:41:02.053Z',
# ...

# %%
from pandas import json_normalize

df=json_normalize(diction)   #converts dictionary to dataframe
df
# Out:
#                                             products  total  skip  limit
# 0  [{'id': 1, 'title': 'Essence Mascara Lash Prin...    194     0     30

# %%
df.iloc[0]
# Out:
# products    [{'id': 1, 'title': 'Essence Mascara Lash Prin...
# total                                                     194
# skip                                                        0
# limit                                                      30
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# products    [{'id': 1, 'title': 'Essence Mascara Lash Prin...
# total                                                     194
# skip                                                        0
# limit                                                      30
# Name: 0, dtype: object

# %%
df.iloc[0][0][1]
# Out:
# /tmp/ipykernel_7039/951512816.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0][1]
# {'id': 2,
#  'title': 'Eyeshadow Palette with Mirror',
#  'description': "The Eyeshadow Palette with Mirror offers a versatile range of eyeshadow shades for creating stunning eye looks. With a built-in mirror, it's convenient for on-the-go makeup application.",
#  'category': 'beauty',
#  'price': 19.99,
#  'discountPercentage': 18.19,
#  'rating': 2.86,
#  'stock': 34,
#  'tags': ['beauty', 'eyeshadow'],
#  'brand': 'Glamour Beauty',
#  'sku': 'BEA-GLA-EYE-002',
#  'weight': 9,
#  'dimensions': {'width': 9.26, 'height': 22.47, 'depth': 27.67},
#  'warrantyInformation': '1 year warranty',
#  'shippingInformation': 'Ships in 2 weeks',
#  'availabilityStatus': 'In Stock',
# ...

# %%
df.loc[0][0][1]['reviews']
# Out:
# /tmp/ipykernel_7039/267471408.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0][1]['reviews']
# [{'rating': 5,
#   'comment': 'Great product!',
#   'date': '2025-04-30T09:41:02.053Z',
#   'reviewerName': 'Savannah Gomez',
#   'reviewerEmail': 'savannah.gomez@x.dummyjson.com'},
#  {'rating': 4,
#   'comment': 'Awesome product!',
#   'date': '2025-04-30T09:41:02.053Z',
#   'reviewerName': 'Christian Perez',
#   'reviewerEmail': 'christian.perez@x.dummyjson.com'},
#  {'rating': 1,
#   'comment': 'Poor quality!',
#   'date': '2025-04-30T09:41:02.053Z',
#   'reviewerName': 'Nicholas Bailey',
#   'reviewerEmail': 'nicholas.bailey@x.dummyjson.com'}]

# %%
df.loc[0][0][1]['reviews'][1]
# Out:
# /tmp/ipykernel_7039/3864318714.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0][1]['reviews'][1]
# {'rating': 4,
#  'comment': 'Awesome product!',
#  'date': '2025-04-30T09:41:02.053Z',
#  'reviewerName': 'Christian Perez',
#  'reviewerEmail': 'christian.perez@x.dummyjson.com'}

# %%
diction['products']
# Out:
# [{'id': 1,
#   'title': 'Essence Mascara Lash Princess',
#   'description': 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.',
#   'category': 'beauty',
#   'price': 9.99,
#   'discountPercentage': 10.48,
#   'rating': 2.56,
#   'stock': 99,
#   'tags': ['beauty', 'mascara'],
#   'brand': 'Essence',
#   'sku': 'BEA-ESS-ESS-001',
#   'weight': 4,
#   'dimensions': {'width': 15.14, 'height': 13.08, 'depth': 22.99},
#   'warrantyInformation': '1 week warranty',
#   'shippingInformation': 'Ships in 3-5 business days',
#   'availabilityStatus': 'In Stock',
#   'reviews': [{'rating': 3,
#     'comment': 'Would not recommend!',
#     'date': '2025-04-30T09:41:02.053Z',
#     'reviewerName': 'Eleanor Collins',
#     'reviewerEmail': 'eleanor.collins@x.dummyjson.com'},
#    {'rating': 4,
#     'comment': 'Very satisfied!',
#     'date': '2025-04-30T09:41:02.053Z',
# ...

# %%
d=json_normalize(diction['products'])
d
# Out:
#     id  ...                                   meta.qrCode
# 0    1  ...  https://cdn.dummyjson.com/public/qr-code.png
# 1    2  ...  https://cdn.dummyjson.com/public/qr-code.png
# 2    3  ...  https://cdn.dummyjson.com/public/qr-code.png
# 3    4  ...  https://cdn.dummyjson.com/public/qr-code.png
# 4    5  ...  https://cdn.dummyjson.com/public/qr-code.png
# 5    6  ...  https://cdn.dummyjson.com/public/qr-code.png
# 6    7  ...  https://cdn.dummyjson.com/public/qr-code.png
# 7    8  ...  https://cdn.dummyjson.com/public/qr-code.png
# 8    9  ...  https://cdn.dummyjson.com/public/qr-code.png
# 9   10  ...  https://cdn.dummyjson.com/public/qr-code.png
# 10  11  ...  https://cdn.dummyjson.com/public/qr-code.png
# 11  12  ...  https://cdn.dummyjson.com/public/qr-code.png
# 12  13  ...  https://cdn.dummyjson.com/public/qr-code.png
# 13  14  ...  https://cdn.dummyjson.com/public/qr-code.png
# 14  15  ...  https://cdn.dummyjson.com/public/qr-code.png
# ...

# %%
d.iloc[0][1]
# Out:
# /tmp/ipykernel_7039/2873583646.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d.iloc[0][1]
# 'Essence Mascara Lash Princess'

# %%
d.loc[0]['description']
# Out:
# 'The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.'
